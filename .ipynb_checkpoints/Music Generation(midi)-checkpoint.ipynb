# %%
from music21 import converter,instrument,chord,stream,note
import glob
import pickle
import numpy as np
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
midi=converter.parse("midi_songs/8.mid")

# %%
midi
# Out:
# <music21.stream.Score 0x1fb73aec278>

# %%
midi.show('midi')
# Out:
#                 <div id='midiPlayerDiv5155'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv5155');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
midi.show('text')
# Out:
# {0.0} <music21.stream.Part 0x1fb73bd1278>
#     {0.0} <music21.instrument.Piano 'Piano'>
#     {0.0} <music21.tempo.MetronomeMark allegrissimo Quarter=140.0>
#     {0.0} <music21.key.Key of C major>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Voice 0x1fb73bf56a0>
#         {0.0} <music21.note.Note C>
#         {1.0} <music21.note.Rest rest>
#         {1.5} <music21.note.Note G>
#         {1.75} <music21.note.Note C>
#         {2.0} <music21.note.Note D>
#         {2.3333} <music21.note.Rest rest>
#         {3.5} <music21.note.Note F>
#         {3.75} <music21.note.Note B->
#         {4.0} <music21.note.Note F>
#         {6.0} <music21.note.Note A>
#         {7.0} <music21.note.Note G>
#         {8.0} <music21.note.Note E>
#         {11.0} <music21.note.Note G>
#         {12.0} <music21.note.Note D>
#         {13.0} <music21.note.Note G>
#         {16.0} <music21.note.Note G>
#         {19.0} <music21.note.Note A>
#         {19.5} <music21.note.Note C>
#         {20.0} <music21.note.Note B->
#         {20.5} <music21.note.Note D>
#         {21.0} <music21.note.Note F>
#         {24.0} <music21.note.Note G>
#         {27.0} <music21.note.Note G>
#         {27.5} <music21.note.Note A>
#         {28.0} <music21.note.Note A>
#         {28.75} <music21.note.Note F>
#         {29.0} <music21.note.Note F>
#         {30.0} <music21.note.Note B->
#         {30.75} <music21.note.Note B->
#         {31.0} <music21.note.Note B->
#         {32.0} <music21.note.Note A>
#         {35.0} <music21.note.Note G>
#         {35.5} <music21.note.Note A>
#         {36.0} <music21.note.Note B->
#         {36.5} <music21.note.Note G>
#         {37.0} <music21.note.Note D>
#         {40.0} <music21.note.Note C>
#         {41.5} <music21.note.Note G>
#         {43.0} <music21.note.Note C>
#         {44.0} <music21.note.Note B->
#         {45.0} <music21.note.Note A>
#         {46.0} <music21.note.Note G>
#         {47.0} <music21.note.Note B->
#         {48.0} <music21.note.Note C>
#         {49.0} <music21.note.Note G>
#         {50.5} <music21.note.Note G>
#         {51.0} <music21.note.Note C>
#         {52.0} <music21.note.Note B->
#         {53.0} <music21.note.Note A>
#         {54.0} <music21.note.Note G>
#         {55.0} <music21.note.Note B->
#         {56.0} <music21.note.Note C>
#         {57.5} <music21.note.Note G>
#         {59.0} <music21.note.Note C>
#         {60.0} <music21.note.Note B->
#         {61.0} <music21.note.Note A>
#         {62.0} <music21.note.Note G>
#         {63.0} <music21.note.Note B->
#         {64.0} <music21.note.Note E>
#         {65.0} <music21.note.Note G>
#         {66.0} <music21.note.Note G>
#         {67.0} <music21.note.Note B->
#         {68.0} <music21.note.Note C>
#         {69.0} <music21.note.Note E>
#         {72.0} <music21.note.Note G>
#         {73.5} <music21.note.Note G>
#         {73.75} <music21.note.Note C>
#         {74.0} <music21.note.Note F>
#         {75.5} <music21.note.Note F>
#         {75.75} <music21.note.Note B->
#         {76.0} <music21.note.Note F>
#         {78.0} <music21.note.Note F>
#         {79.0} <music21.note.Note G>
#         {80.0} <music21.note.Note C>
#         {80.6667} <music21.note.Rest rest>
#     {0.0} <music21.stream.Voice 0x1fb73c806d8>
#         {0.0} <music21.note.Note E>
#         {2.0} <music21.chord.Chord D4 B-4>
#         {4.0} <music21.chord.Chord C4 A4>
#         {6.0} <music21.chord.Chord C4 A4>
#         {7.0} <music21.chord.Chord D4 B4>
#         {8.0} <music21.note.Note C>
#         {11.5} <music21.note.Note C>
#         {12.75} <music21.note.Note G>
#         {16.0} <music21.note.Note C>
#         {19.0} <music21.note.Note G>
#         {19.5} <music21.note.Note C>
#         {20.0} <music21.note.Note B->
#         {20.5} <music21.note.Note B->
#         {20.75} <music21.note.Note C>
#         {21.0} <music21.note.Note D>
#         {24.0} <music21.note.Note E>
#         {27.0} <music21.note.Note D>
#         {27.5} <music21.note.Note E>
#         {28.0} <music21.note.Note F>
#         {28.75} <music21.note.Note D>
#         {29.0} <music21.note.Note D>
#         {30.0} <music21.note.Note B->
#         {30.75} <music21.note.Note F>
#         {31.0} <music21.note.Note F>
#         {32.0} <music21.note.Note E>
#         {35.0} <music21.note.Note D>
#         {35.5} <music21.note.Note E>
#         {36.0} <music21.note.Note F>
#         {36.5} <music21.note.Note D>
#         {36.75} <music21.note.Note B->
#         {37.0} <music21.note.Note B->
#         {40.0} <music21.note.Note G>
#         {41.5} <music21.note.Note C>
#         {43.0} <music21.note.Note G>
#         {45.5} <music21.note.Note D>
#         {47.0} <music21.note.Note F>
#         {48.0} <music21.note.Note E>
#         {48.5} <music21.note.Note E>
#         {48.75} <music21.note.Note F>
#         {49.5} <music21.note.Note G>
#         {51.5} <music21.note.Note G>
#         {53.5} <music21.note.Note D>
#         {55.0} <music21.note.Note E>
#         {55.5} <music21.note.Note F>
#         {56.0} <music21.note.Note G>
#         {57.5} <music21.note.Note C>
#         {59.0} <music21.note.Note G>
#         {61.5} <music21.note.Note D>
#         {63.0} <music21.note.Note F>
#         {64.5} <music21.note.Note E>
#         {64.75} <music21.note.Note F>
#         {66.5} <music21.note.Note G>
#         {66.75} <music21.note.Note A>
#         {68.5} <music21.note.Note C>
#         {68.75} <music21.note.Note D>
#         {70.0} <music21.note.Note C>
#         {71.0} <music21.note.Note B->
#         {72.0} <music21.chord.Chord E4 C5>
#         {74.0} <music21.chord.Chord D4 B-4>
#         {76.0} <music21.chord.Chord C4 A4>
#         {78.0} <music21.chord.Chord C4 A4>
#         {79.0} <music21.chord.Chord D4 B4>
#         {80.0} <music21.chord.Chord G3 C4>
#     {0.0} <music21.stream.Voice 0x1fb73d02048>
#         {0.0} <music21.note.Rest rest>
#         {12.75} <music21.note.Note B->
#         {12.75} <music21.note.Rest rest>
#         {13.0} <music21.note.Note B->
#         {20.75} <music21.note.Note C>
#         {36.75} <music21.note.Note F>
#         {80.0} <music21.chord.Chord E4 C5 G5>
#         {81.0} <music21.note.Rest rest>
#     {0.0} <music21.stream.Voice 0x1fb73d02780>
#         {80.0} <music21.note.Note E>
#     {0.5} <music21.tempo.MetronomeMark allegrissimo Quarter=140.0>
#     {1.75} <music21.tempo.MetronomeMark allegrissimo Quarter=140.0>
# {0.0} <music21.stream.Part 0x1fb73d02a90>
#     {0.0} <music21.instrument.Piano 'Piano'>
#     {0.0} <music21.key.Key of C major>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Voice 0x1fb73cd0588>
#         {0.0} <music21.note.Note C>
#         {2.0} <music21.note.Note B->
#         {4.0} <music21.note.Note F>
#         {6.0} <music21.note.Note F>
#         {7.0} <music21.note.Note G>
#         {8.0} <music21.note.Note C>
#         {10.0} <music21.note.Note C>
#         {12.0} <music21.note.Note G>
#         {14.0} <music21.note.Note G>
#         {16.0} <music21.note.Note C>
#         {18.0} <music21.note.Note C>
#         {20.0} <music21.note.Note G>
#         {22.0} <music21.note.Note G>
#         {24.0} <music21.note.Note C>
#         {26.0} <music21.note.Note C>
#         {28.0} <music21.note.Note G>
#         {30.0} <music21.note.Note G>
#         {32.0} <music21.note.Note C>
#         {34.0} <music21.note.Note C>
#         {36.0} <music21.note.Note G>
#         {38.0} <music21.note.Note G>
#         {40.0} <music21.note.Note C>
#         {42.0} <music21.note.Note C>
#         {44.0} <music21.note.Note G>
#         {46.0} <music21.note.Note G>
#         {48.0} <music21.note.Note C>
#         {50.0} <music21.note.Note C>
#         {52.0} <music21.note.Note G>
#         {54.0} <music21.note.Note G>
#         {56.0} <music21.note.Note C>
#         {58.0} <music21.note.Note C>
#         {60.0} <music21.note.Note G>
#         {62.0} <music21.note.Note G>
#         {64.0} <music21.note.Note C>
#         {66.0} <music21.note.Note C>
#         {68.0} <music21.note.Note G>
#         {70.0} <music21.note.Note G>
#         {72.0} <music21.note.Note C>
#         {74.0} <music21.note.Note B->
#         {76.0} <music21.note.Note F>
#         {78.0} <music21.note.Note F>
#         {79.0} <music21.note.Note G>
#         {80.0} <music21.chord.Chord G4 C4>
#     {0.0} <music21.stream.Voice 0x1fb73d243c8>
#         {80.0} <music21.chord.Chord C2 C3>
# {0.0} <music21.stream.Part 0x1fb73d24588>
#     {0.0} <music21.instrument.Piano 'Piano'>
#     {0.0} <music21.key.Key of C major>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Voice 0x1fb73d35080>
#         {0.0} <music21.note.Note C>
#         {1.0} <music21.note.Rest rest>
#         {1.6667} <music21.note.Note G>
#         {2.0} <music21.note.Note D>
#         {2.3333} <music21.note.Rest rest>
#         {3.6667} <music21.note.Note F>
#         {4.0} <music21.note.Note F>
#         {6.0} <music21.note.Note A>
#         {7.0} <music21.note.Note G>
#         {8.0} <music21.note.Note E>
#         {11.0} <music21.note.Note G>
#         {12.0} <music21.note.Note D>
#         {13.0} <music21.note.Note G>
#         {16.0} <music21.note.Note G>
#         {19.0} <music21.note.Note A>
#         {19.6667} <music21.note.Note C>
#         {20.0} <music21.note.Note B->
#         {20.6667} <music21.note.Note D>
#         {21.0} <music21.note.Note F>
#         {24.0} <music21.note.Note G>
#         {27.0} <music21.note.Note G>
#         {27.6667} <music21.note.Note A>
#         {28.0} <music21.note.Note A>
#         {28.75} <music21.note.Note F>
#         {29.0} <music21.note.Note F>
#         {30.0} <music21.note.Note B->
#         {30.75} <music21.note.Note B->
#         {31.0} <music21.note.Note B->
#         {32.0} <music21.note.Note A>
#         {35.0} <music21.note.Note G>
#         {35.6667} <music21.note.Note A>
#         {36.0} <music21.note.Note B->
#         {36.6667} <music21.note.Note G>
#         {37.0} <music21.note.Note D>
#         {40.0} <music21.note.Note C>
#         {41.6667} <music21.note.Note G>
#         {43.0} <music21.note.Note C>
#         {44.0} <music21.note.Note B->
#         {45.0} <music21.note.Note A>
#         {46.0} <music21.note.Note G>
#         {47.0} <music21.note.Note B->
#         {48.0} <music21.note.Note C>
#         {49.0} <music21.note.Note G>
#         {50.6667} <music21.note.Note G>
#         {51.6667} <music21.note.Note G>
#         {53.0} <music21.note.Note A>
#         {54.0} <music21.note.Note G>
#         {55.0} <music21.note.Note B->
#         {56.0} <music21.note.Note C>
#         {57.6667} <music21.note.Note G>
#         {59.0} <music21.note.Note C>
#         {60.0} <music21.note.Note B->
#         {61.0} <music21.note.Note A>
#         {62.0} <music21.note.Note G>
#         {63.0} <music21.note.Note B->
#         {64.0} <music21.note.Note E>
#         {65.0} <music21.note.Note G>
#         {66.0} <music21.note.Note G>
#         {67.0} <music21.note.Note B->
#         {68.0} <music21.note.Note C>
#         {69.0} <music21.note.Note E>
#         {72.0} <music21.note.Note G>
#         {73.6667} <music21.note.Note G>
#         {74.0} <music21.note.Note F>
#         {75.6667} <music21.note.Note F>
#         {76.0} <music21.note.Note F>
#         {78.0} <music21.note.Note F>
#         {79.0} <music21.note.Note G>
#         {80.0} <music21.note.Note C>
#         {80.6667} <music21.note.Rest rest>
#     {0.0} <music21.stream.Voice 0x1fb73d50f60>
#         {0.0} <music21.note.Note E>
#         {1.75} <music21.note.Note C>
#         {2.0} <music21.chord.Chord D4 B-4>
#         {3.75} <music21.note.Note B->
#         {4.0} <music21.chord.Chord C4 A4>
#         {6.0} <music21.chord.Chord C4 A4>
#         {7.0} <music21.chord.Chord D4 B4>
#         {8.0} <music21.note.Note C>
#         {11.6667} <music21.note.Note C>
#         {12.75} <music21.note.Note G>
#         {16.0} <music21.note.Note C>
#         {19.0} <music21.note.Note G>
#         {19.6667} <music21.note.Note C>
#         {20.6667} <music21.note.Note B->
#         {21.0} <music21.note.Note D>
#         {24.0} <music21.note.Note E>
#         {27.0} <music21.note.Note D>
#         {27.6667} <music21.note.Note E>
#         {28.75} <music21.note.Note D>
#         {29.0} <music21.note.Note D>
#         {30.0} <music21.note.Note B->
#         {30.75} <music21.note.Note F>
#         {31.0} <music21.note.Note F>
#         {32.0} <music21.note.Note E>
#         {35.0} <music21.note.Note D>
#         {35.6667} <music21.note.Note E>
#         {36.6667} <music21.note.Note D>
#         {37.0} <music21.note.Note B->
#         {40.0} <music21.note.Note G>
#         {41.6667} <music21.note.Note C>
#         {43.0} <music21.note.Note G>
#         {45.6667} <music21.note.Note D>
#         {47.0} <music21.note.Note F>
#         {48.0} <music21.note.Note E>
#         {48.6667} <music21.note.Note E>
#         {49.6667} <music21.note.Note G>
#         {51.0} <music21.note.Note C>
#         {52.0} <music21.note.Note B->
#         {53.6667} <music21.note.Note D>
#         {55.0} <music21.note.Note E>
#         {55.6667} <music21.note.Note F>
#         {57.6667} <music21.note.Note C>
#         {59.0} <music21.note.Note G>
#         {61.6667} <music21.note.Note D>
#         {63.0} <music21.note.Note F>
#         {64.6667} <music21.note.Note E>
#         {66.6667} <music21.note.Note G>
#         {68.6667} <music21.note.Note C>
#         {70.0} <music21.note.Note C>
#         {71.0} <music21.note.Note B->
#         {72.0} <music21.chord.Chord E4 C5>
#         {73.75} <music21.note.Note C>
#         {74.0} <music21.chord.Chord D4 B-4>
#         {75.75} <music21.note.Note B->
#         {76.0} <music21.chord.Chord C4 A4>
#         {78.0} <music21.chord.Chord C4 A4>
#         {79.0} <music21.chord.Chord D4 B4>
#         {80.0} <music21.chord.Chord G3 C4>
#     {0.0} <music21.stream.Voice 0x1fb73d8cc18>
#         {0.0} <music21.note.Rest rest>
#         {12.75} <music21.note.Note B->
#         {12.75} <music21.note.Rest rest>
#         {13.0} <music21.note.Note B->
#         {20.0} <music21.note.Note B->
#         {20.75} <music21.note.Note C>
#         {28.0} <music21.note.Note F>
#         {36.0} <music21.note.Note F>
#         {36.75} <music21.note.Note B->
#         {48.75} <music21.note.Note F>
#         {56.0} <music21.note.Note G>
#         {64.75} <music21.note.Note F>
#         {66.75} <music21.note.Note A>
#         {68.75} <music21.note.Note D>
#         {80.0} <music21.chord.Chord E4 C5 G5>
#         {81.0} <music21.note.Rest rest>
#     {0.0} <music21.stream.Voice 0x1fb73da2940>
#         {20.75} <music21.note.Note C>
#         {36.75} <music21.note.Note F>
#         {80.0} <music21.note.Note E>
# {0.0} <music21.stream.Part 0x1fb73da2b70>
#     {0.0} <music21.instrument.Piano 'Piano'>
#     {0.0} <music21.key.Key of C major>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Voice 0x1fb73db5668>
#         {0.0} <music21.note.Note C>
#         {2.0} <music21.note.Note B->
#         {4.0} <music21.note.Note F>
#         {6.0} <music21.note.Note F>
#         {7.0} <music21.note.Note G>
#         {8.0} <music21.note.Note C>
#         {10.0} <music21.note.Note C>
#         {12.0} <music21.note.Note G>
#         {14.0} <music21.note.Note G>
#         {16.0} <music21.note.Note C>
#         {18.0} <music21.note.Note C>
#         {20.0} <music21.note.Note G>
#         {22.0} <music21.note.Note G>
#         {24.0} <music21.note.Note C>
#         {26.0} <music21.note.Note C>
#         {28.0} <music21.note.Note G>
#         {30.0} <music21.note.Note G>
#         {32.0} <music21.note.Note C>
#         {34.0} <music21.note.Note C>
#         {36.0} <music21.note.Note G>
#         {38.0} <music21.note.Note G>
#         {40.0} <music21.note.Note C>
#         {42.0} <music21.note.Note C>
#         {44.0} <music21.note.Note G>
#         {46.0} <music21.note.Note G>
#         {48.0} <music21.note.Note C>
#         {50.0} <music21.note.Note C>
#         {52.0} <music21.note.Note G>
#         {54.0} <music21.note.Note G>
#         {56.0} <music21.note.Note C>
#         {58.0} <music21.note.Note C>
#         {60.0} <music21.note.Note G>
#         {62.0} <music21.note.Note G>
#         {64.0} <music21.note.Note C>
#         {66.0} <music21.note.Note C>
#         {68.0} <music21.note.Note G>
#         {70.0} <music21.note.Note G>
#         {72.0} <music21.note.Note C>
#         {74.0} <music21.note.Note B->
#         {76.0} <music21.note.Note F>
#         {78.0} <music21.note.Note F>
#         {79.0} <music21.note.Note G>
#         {80.0} <music21.chord.Chord G4 C4>
#     {0.0} <music21.stream.Voice 0x1fb73de84a8>
#         {80.0} <music21.chord.Chord C2 C3>

# %%
elements_to_parse=midi.flat.notes

# %%
len(elements_to_parse)
# Out:
# 370

# %%
isinstance(elements_to_parse[34],note.Note)#tell us whether this is note or not
# Out:
# True

# %%
elements_to_parse[34]
# Out:
# <music21.note.Note G>

# %%
str(elements_to_parse[34].pitch)
# Out:
# 'G1'

# %%
isinstance(elements_to_parse[11],chord.Chord)#tells us whether that is chord or not
# Out:
# True

# %%
elements_to_parse[11].normalOrder #will get all the elemnets present in that chord
# Out:
# [10, 2]

# %%
'+'.join(str(n) for n in elements_to_parse[11].normalOrder)#making it a single string
# Out:
# '10+2'

# %%
for e in elements_to_parse:
    print(e,e.offset)#offset defines the time when this note is played
# Out:
# <music21.note.Note C> 0.0
# <music21.note.Note E> 0.0
# <music21.note.Note C> 0.0
# <music21.note.Note C> 0.0
# <music21.note.Note E> 0.0
# <music21.note.Note C> 0.0
# <music21.note.Note G> 1.5
# <music21.note.Note G> 5/3
# <music21.note.Note C> 1.75
# <music21.note.Note C> 1.75
# <music21.note.Note D> 2.0
# <music21.chord.Chord D4 B-4> 2.0
# <music21.note.Note B-> 2.0
# <music21.note.Note D> 2.0
# <music21.chord.Chord D4 B-4> 2.0
# <music21.note.Note B-> 2.0
# <music21.note.Note F> 3.5
# <music21.note.Note F> 11/3
# <music21.note.Note B-> 3.75
# <music21.note.Note B-> 3.75
# <music21.note.Note F> 4.0
# <music21.chord.Chord C4 A4> 4.0
# <music21.note.Note F> 4.0
# <music21.note.Note F> 4.0
# <music21.chord.Chord C4 A4> 4.0
# <music21.note.Note F> 4.0
# <music21.note.Note A> 6.0
# <music21.chord.Chord C4 A4> 6.0
# <music21.note.Note F> 6.0
# <music21.note.Note A> 6.0
# <music21.chord.Chord C4 A4> 6.0
# <music21.note.Note F> 6.0
# <music21.note.Note G> 7.0
# <music21.chord.Chord D4 B4> 7.0
# <music21.note.Note G> 7.0
# <music21.note.Note G> 7.0
# <music21.chord.Chord D4 B4> 7.0
# <music21.note.Note G> 7.0
# <music21.note.Note E> 8.0
# <music21.note.Note C> 8.0
# <music21.note.Note C> 8.0
# <music21.note.Note E> 8.0
# <music21.note.Note C> 8.0
# <music21.note.Note C> 8.0
# <music21.note.Note C> 10.0
# <music21.note.Note C> 10.0
# <music21.note.Note G> 11.0
# <music21.note.Note G> 11.0
# <music21.note.Note C> 11.5
# <music21.note.Note C> 35/3
# <music21.note.Note D> 12.0
# <music21.note.Note G> 12.0
# <music21.note.Note D> 12.0
# <music21.note.Note G> 12.0
# <music21.note.Note G> 12.75
# <music21.note.Note B-> 12.75
# <music21.note.Note G> 12.75
# <music21.note.Note B-> 12.75
# <music21.note.Note G> 13.0
# <music21.note.Note B-> 13.0
# <music21.note.Note G> 13.0
# <music21.note.Note B-> 13.0
# <music21.note.Note G> 14.0
# <music21.note.Note G> 14.0
# <music21.note.Note G> 16.0
# <music21.note.Note C> 16.0
# <music21.note.Note C> 16.0
# <music21.note.Note G> 16.0
# <music21.note.Note C> 16.0
# <music21.note.Note C> 16.0
# <music21.note.Note C> 18.0
# <music21.note.Note C> 18.0
# <music21.note.Note A> 19.0
# <music21.note.Note G> 19.0
# <music21.note.Note A> 19.0
# <music21.note.Note G> 19.0
# <music21.note.Note C> 19.5
# <music21.note.Note C> 19.5
# <music21.note.Note C> 59/3
# <music21.note.Note C> 59/3
# <music21.note.Note B-> 20.0
# <music21.note.Note B-> 20.0
# <music21.note.Note G> 20.0
# <music21.note.Note B-> 20.0
# <music21.note.Note B-> 20.0
# <music21.note.Note G> 20.0
# <music21.note.Note D> 20.5
# <music21.note.Note B-> 20.5
# <music21.note.Note D> 62/3
# <music21.note.Note B-> 62/3
# <music21.note.Note C> 20.75
# <music21.note.Note C> 20.75
# <music21.note.Note C> 20.75
# <music21.note.Note C> 20.75
# <music21.note.Note F> 21.0
# <music21.note.Note D> 21.0
# <music21.note.Note F> 21.0
# <music21.note.Note D> 21.0
# <music21.note.Note G> 22.0
# <music21.note.Note G> 22.0
# <music21.note.Note G> 24.0
# <music21.note.Note E> 24.0
# <music21.note.Note C> 24.0
# <music21.note.Note G> 24.0
# <music21.note.Note E> 24.0
# <music21.note.Note C> 24.0
# <music21.note.Note C> 26.0
# <music21.note.Note C> 26.0
# <music21.note.Note G> 27.0
# <music21.note.Note D> 27.0
# <music21.note.Note G> 27.0
# <music21.note.Note D> 27.0
# <music21.note.Note A> 27.5
# <music21.note.Note E> 27.5
# <music21.note.Note A> 83/3
# <music21.note.Note E> 83/3
# <music21.note.Note A> 28.0
# <music21.note.Note F> 28.0
# <music21.note.Note G> 28.0
# <music21.note.Note A> 28.0
# <music21.note.Note F> 28.0
# <music21.note.Note G> 28.0
# <music21.note.Note F> 28.75
# <music21.note.Note D> 28.75
# <music21.note.Note F> 28.75
# <music21.note.Note D> 28.75
# <music21.note.Note F> 29.0
# <music21.note.Note D> 29.0
# <music21.note.Note F> 29.0
# <music21.note.Note D> 29.0
# <music21.note.Note B-> 30.0
# <music21.note.Note B-> 30.0
# <music21.note.Note G> 30.0
# <music21.note.Note B-> 30.0
# <music21.note.Note B-> 30.0
# <music21.note.Note G> 30.0
# <music21.note.Note B-> 30.75
# <music21.note.Note F> 30.75
# <music21.note.Note B-> 30.75
# <music21.note.Note F> 30.75
# <music21.note.Note B-> 31.0
# <music21.note.Note F> 31.0
# <music21.note.Note B-> 31.0
# <music21.note.Note F> 31.0
# <music21.note.Note A> 32.0
# <music21.note.Note E> 32.0
# <music21.note.Note C> 32.0
# <music21.note.Note A> 32.0
# <music21.note.Note E> 32.0
# <music21.note.Note C> 32.0
# <music21.note.Note C> 34.0
# <music21.note.Note C> 34.0
# <music21.note.Note G> 35.0
# <music21.note.Note D> 35.0
# <music21.note.Note G> 35.0
# <music21.note.Note D> 35.0
# <music21.note.Note A> 35.5
# <music21.note.Note E> 35.5
# <music21.note.Note A> 107/3
# <music21.note.Note E> 107/3
# <music21.note.Note B-> 36.0
# <music21.note.Note F> 36.0
# <music21.note.Note G> 36.0
# <music21.note.Note B-> 36.0
# <music21.note.Note F> 36.0
# <music21.note.Note G> 36.0
# <music21.note.Note G> 36.5
# <music21.note.Note D> 36.5
# <music21.note.Note G> 110/3
# <music21.note.Note D> 110/3
# <music21.note.Note B-> 36.75
# <music21.note.Note F> 36.75
# <music21.note.Note B-> 36.75
# <music21.note.Note F> 36.75
# <music21.note.Note D> 37.0
# <music21.note.Note B-> 37.0
# <music21.note.Note D> 37.0
# <music21.note.Note B-> 37.0
# <music21.note.Note G> 38.0
# <music21.note.Note G> 38.0
# <music21.note.Note C> 40.0
# <music21.note.Note G> 40.0
# <music21.note.Note C> 40.0
# <music21.note.Note C> 40.0
# <music21.note.Note G> 40.0
# <music21.note.Note C> 40.0
# <music21.note.Note G> 41.5
# <music21.note.Note C> 41.5
# <music21.note.Note G> 125/3
# <music21.note.Note C> 125/3
# <music21.note.Note C> 42.0
# <music21.note.Note C> 42.0
# <music21.note.Note C> 43.0
# <music21.note.Note G> 43.0
# <music21.note.Note C> 43.0
# <music21.note.Note G> 43.0
# <music21.note.Note B-> 44.0
# <music21.note.Note G> 44.0
# <music21.note.Note B-> 44.0
# <music21.note.Note G> 44.0
# <music21.note.Note A> 45.0
# <music21.note.Note A> 45.0
# <music21.note.Note D> 45.5
# <music21.note.Note D> 137/3
# <music21.note.Note G> 46.0
# <music21.note.Note G> 46.0
# <music21.note.Note G> 46.0
# <music21.note.Note G> 46.0
# <music21.note.Note B-> 47.0
# <music21.note.Note F> 47.0
# <music21.note.Note B-> 47.0
# <music21.note.Note F> 47.0
# <music21.note.Note C> 48.0
# <music21.note.Note E> 48.0
# <music21.note.Note C> 48.0
# <music21.note.Note C> 48.0
# <music21.note.Note E> 48.0
# <music21.note.Note C> 48.0
# <music21.note.Note E> 48.5
# <music21.note.Note E> 146/3
# <music21.note.Note F> 48.75
# <music21.note.Note F> 48.75
# <music21.note.Note G> 49.0
# <music21.note.Note G> 49.0
# <music21.note.Note G> 49.5
# <music21.note.Note G> 149/3
# <music21.note.Note C> 50.0
# <music21.note.Note C> 50.0
# <music21.note.Note G> 50.5
# <music21.note.Note G> 152/3
# <music21.note.Note C> 51.0
# <music21.note.Note C> 51.0
# <music21.note.Note G> 51.5
# <music21.note.Note G> 155/3
# <music21.note.Note B-> 52.0
# <music21.note.Note G> 52.0
# <music21.note.Note B-> 52.0
# <music21.note.Note G> 52.0
# <music21.note.Note A> 53.0
# <music21.note.Note A> 53.0
# <music21.note.Note D> 53.5
# <music21.note.Note D> 161/3
# <music21.note.Note G> 54.0
# <music21.note.Note G> 54.0
# <music21.note.Note G> 54.0
# <music21.note.Note G> 54.0
# <music21.note.Note B-> 55.0
# <music21.note.Note E> 55.0
# <music21.note.Note B-> 55.0
# <music21.note.Note E> 55.0
# <music21.note.Note F> 55.5
# <music21.note.Note F> 167/3
# <music21.note.Note C> 56.0
# <music21.note.Note G> 56.0
# <music21.note.Note C> 56.0
# <music21.note.Note C> 56.0
# <music21.note.Note G> 56.0
# <music21.note.Note C> 56.0
# <music21.note.Note G> 57.5
# <music21.note.Note C> 57.5
# <music21.note.Note G> 173/3
# <music21.note.Note C> 173/3
# <music21.note.Note C> 58.0
# <music21.note.Note C> 58.0
# <music21.note.Note C> 59.0
# <music21.note.Note G> 59.0
# <music21.note.Note C> 59.0
# <music21.note.Note G> 59.0
# <music21.note.Note B-> 60.0
# <music21.note.Note G> 60.0
# <music21.note.Note B-> 60.0
# <music21.note.Note G> 60.0
# <music21.note.Note A> 61.0
# <music21.note.Note A> 61.0
# <music21.note.Note D> 61.5
# <music21.note.Note D> 185/3
# <music21.note.Note G> 62.0
# <music21.note.Note G> 62.0
# <music21.note.Note G> 62.0
# <music21.note.Note G> 62.0
# <music21.note.Note B-> 63.0
# <music21.note.Note F> 63.0
# <music21.note.Note B-> 63.0
# <music21.note.Note F> 63.0
# <music21.note.Note E> 64.0
# <music21.note.Note C> 64.0
# <music21.note.Note E> 64.0
# <music21.note.Note C> 64.0
# <music21.note.Note E> 64.5
# <music21.note.Note E> 194/3
# <music21.note.Note F> 64.75
# <music21.note.Note F> 64.75
# <music21.note.Note G> 65.0
# <music21.note.Note G> 65.0
# <music21.note.Note G> 66.0
# <music21.note.Note C> 66.0
# <music21.note.Note G> 66.0
# <music21.note.Note C> 66.0
# <music21.note.Note G> 66.5
# <music21.note.Note G> 200/3
# <music21.note.Note A> 66.75
# <music21.note.Note A> 66.75
# <music21.note.Note B-> 67.0
# <music21.note.Note B-> 67.0
# <music21.note.Note C> 68.0
# <music21.note.Note G> 68.0
# <music21.note.Note C> 68.0
# <music21.note.Note G> 68.0
# <music21.note.Note C> 68.5
# <music21.note.Note C> 206/3
# <music21.note.Note D> 68.75
# <music21.note.Note D> 68.75
# <music21.note.Note E> 69.0
# <music21.note.Note E> 69.0
# <music21.note.Note C> 70.0
# <music21.note.Note G> 70.0
# <music21.note.Note C> 70.0
# <music21.note.Note G> 70.0
# <music21.note.Note B-> 71.0
# <music21.note.Note B-> 71.0
# <music21.note.Note G> 72.0
# <music21.chord.Chord E4 C5> 72.0
# <music21.note.Note C> 72.0
# <music21.note.Note G> 72.0
# <music21.chord.Chord E4 C5> 72.0
# <music21.note.Note C> 72.0
# <music21.note.Note G> 73.5
# <music21.note.Note G> 221/3
# <music21.note.Note C> 73.75
# <music21.note.Note C> 73.75
# <music21.note.Note F> 74.0
# <music21.chord.Chord D4 B-4> 74.0
# <music21.note.Note B-> 74.0
# <music21.note.Note F> 74.0
# <music21.chord.Chord D4 B-4> 74.0
# <music21.note.Note B-> 74.0
# <music21.note.Note F> 75.5
# <music21.note.Note F> 227/3
# <music21.note.Note B-> 75.75
# <music21.note.Note B-> 75.75
# <music21.note.Note F> 76.0
# <music21.chord.Chord C4 A4> 76.0
# <music21.note.Note F> 76.0
# <music21.note.Note F> 76.0
# <music21.chord.Chord C4 A4> 76.0
# <music21.note.Note F> 76.0
# <music21.note.Note F> 78.0
# <music21.chord.Chord C4 A4> 78.0
# <music21.note.Note F> 78.0
# <music21.note.Note F> 78.0
# <music21.chord.Chord C4 A4> 78.0
# <music21.note.Note F> 78.0
# <music21.note.Note G> 79.0
# <music21.chord.Chord D4 B4> 79.0
# <music21.note.Note G> 79.0
# <music21.note.Note G> 79.0
# <music21.chord.Chord D4 B4> 79.0
# <music21.note.Note G> 79.0
# <music21.note.Note C> 80.0
# <music21.chord.Chord G3 C4> 80.0
# <music21.chord.Chord E4 C5 G5> 80.0
# <music21.note.Note E> 80.0
# <music21.chord.Chord G4 C4> 80.0
# <music21.chord.Chord C2 C3> 80.0
# <music21.note.Note C> 80.0
# <music21.chord.Chord G3 C4> 80.0
# <music21.chord.Chord E4 C5 G5> 80.0
# <music21.note.Note E> 80.0
# <music21.chord.Chord G4 C4> 80.0
# <music21.chord.Chord C2 C3> 80.0

# %%
notes_demo=[]
for elements in elements_to_parse:
    if isinstance(elements,note.Note):
        notes_demo.append(str(elements.pitch))
    elif isinstance(elements,chord.Chord):
        notes_demo.append('+'.join(str(n) for n in elements.normalOrder))

# %%
notes_demo
# Out:
# ['C5',
#  'E4',
#  'C2',
#  'C5',
#  'E4',
#  'C2',
#  'G4',
#  'G4',
#  'C5',
#  'C5',
#  'D5',
#  '10+2',
#  'B-1',
#  'D5',
#  '10+2',
#  'B-1',
#  'F4',
#  'F4',
#  'B-4',
#  'B-4',
#  'F5',
#  '9+0',
#  'F1',
#  'F5',
#  '9+0',
#  'F1',
#  'A5',
#  '9+0',
#  'F1',
#  'A5',
#  '9+0',
#  'F1',
#  'G5',
#  '11+2',
#  'G1',
#  'G5',
#  '11+2',
#  'G1',
#  'E5',
#  'C5',
#  'C2',
#  'E5',
#  'C5',
#  'C2',
#  'C2',
#  'C2',
#  'G4',
#  'G4',
#  'C5',
#  'C5',
#  'D5',
#  'G1',
#  'D5',
#  'G1',
#  'G4',
#  'B-4',
#  'G4',
#  'B-4',
#  'G4',
#  'B-4',
#  'G4',
#  'B-4',
#  'G1',
#  'G1',
#  'G4',
#  'C5',
#  'C2',
#  'G4',
#  'C5',
#  'C2',
#  'C2',
#  'C2',
#  'A3',
#  'G4',
#  'A3',
#  'G4',
#  'C4',
#  'C5',
#  'C4',
#  'C5',
#  'B-3',
#  'B-4',
#  'G1',
#  'B-3',
#  'B-4',
#  'G1',
#  'D4',
#  'B-4',
#  'D4',
#  'B-4',
#  'C4',
#  'C5',
#  'C4',
#  'C5',
#  'F4',
#  'D5',
#  'F4',
#  'D5',
#  'G1',
#  'G1',
#  'G4',
#  'E5',
#  'C2',
#  'G4',
#  'E5',
#  'C2',
#  'C2',
#  'C2',
#  'G4',
#  'D5',
#  'G4',
#  'D5',
#  'A4',
#  'E5',
#  'A4',
#  'E5',
#  'A4',
#  'F5',
#  'G1',
#  'A4',
#  'F5',
#  'G1',
#  'F4',
#  'D5',
#  'F4',
#  'D5',
#  'F4',
#  'D5',
#  'F4',
#  'D5',
#  'B-4',
#  'B-5',
#  'G1',
#  'B-4',
#  'B-5',
#  'G1',
#  'B-4',
#  'F5',
#  'B-4',
#  'F5',
#  'B-4',
#  'F5',
#  'B-4',
#  'F5',
#  'A4',
#  'E5',
#  'C2',
#  'A4',
#  'E5',
#  'C2',
#  'C2',
#  'C2',
#  'G4',
#  'D5',
#  'G4',
#  'D5',
#  'A4',
#  'E5',
#  'A4',
#  'E5',
#  'B-4',
#  'F5',
#  'G1',
#  'B-4',
#  'F5',
#  'G1',
#  'G4',
#  'D5',
#  'G4',
#  'D5',
#  'B-4',
#  'F5',
#  'B-4',
#  'F5',
#  'D5',
#  'B-5',
#  'D5',
#  'B-5',
#  'G1',
#  'G1',
#  'C5',
#  'G4',
#  'C2',
#  'C5',
#  'G4',
#  'C2',
#  'G5',
#  'C5',
#  'G5',
#  'C5',
#  'C2',
#  'C2',
#  'C5',
#  'G4',
#  'C5',
#  'G4',
#  'B-4',
#  'G1',
#  'B-4',
#  'G1',
#  'A4',
#  'A4',
#  'D5',
#  'D5',
#  'G4',
#  'G1',
#  'G4',
#  'G1',
#  'B-4',
#  'F4',
#  'B-4',
#  'F4',
#  'C5',
#  'E4',
#  'C2',
#  'C5',
#  'E4',
#  'C2',
#  'E4',
#  'E4',
#  'F4',
#  'F4',
#  'G4',
#  'G4',
#  'G5',
#  'G5',
#  'C2',
#  'C2',
#  'G4',
#  'G4',
#  'C5',
#  'C5',
#  'G4',
#  'G4',
#  'B-4',
#  'G1',
#  'B-4',
#  'G1',
#  'A4',
#  'A4',
#  'D5',
#  'D5',
#  'G4',
#  'G1',
#  'G4',
#  'G1',
#  'B-4',
#  'E4',
#  'B-4',
#  'E4',
#  'F4',
#  'F4',
#  'C5',
#  'G4',
#  'C2',
#  'C5',
#  'G4',
#  'C2',
#  'G5',
#  'C5',
#  'G5',
#  'C5',
#  'C2',
#  'C2',
#  'C5',
#  'G4',
#  'C5',
#  'G4',
#  'B-4',
#  'G1',
#  'B-4',
#  'G1',
#  'A4',
#  'A4',
#  'D5',
#  'D5',
#  'G4',
#  'G1',
#  'G4',
#  'G1',
#  'B-4',
#  'F4',
#  'B-4',
#  'F4',
#  'E4',
#  'C2',
#  'E4',
#  'C2',
#  'E4',
#  'E4',
#  'F4',
#  'F4',
#  'G4',
#  'G4',
#  'G4',
#  'C2',
#  'G4',
#  'C2',
#  'G4',
#  'G4',
#  'A4',
#  'A4',
#  'B-4',
#  'B-4',
#  'C5',
#  'G1',
#  'C5',
#  'G1',
#  'C5',
#  'C5',
#  'D5',
#  'D5',
#  'E5',
#  'E5',
#  'C5',
#  'G1',
#  'C5',
#  'G1',
#  'B-4',
#  'B-4',
#  'G5',
#  '0+4',
#  'C2',
#  'G5',
#  '0+4',
#  'C2',
#  'G4',
#  'G4',
#  'C5',
#  'C5',
#  'F5',
#  '10+2',
#  'B-1',
#  'F5',
#  '10+2',
#  'B-1',
#  'F4',
#  'F4',
#  'B-4',
#  'B-4',
#  'F3',
#  '9+0',
#  'F1',
#  'F3',
#  '9+0',
#  'F1',
#  'F3',
#  '9+0',
#  'F1',
#  'F3',
#  '9+0',
#  'F1',
#  'G3',
#  '11+2',
#  'G1',
#  'G3',
#  '11+2',
#  'G1',
#  'C6',
#  '7+0',
#  '0+4+7',
#  'E5',
#  '7+0',
#  '0',
#  'C6',
#  '7+0',
#  '0+4+7',
#  'E5',
#  '7+0',
#  '0']

# %%
len(notes_demo)
# Out:
# 370

# %% [markdown]
# # processing all the files

# %%
notes=[]
for file in glob.glob('midi_songs/*.mid'):
    midi=converter.parse(file)
    elements_to_parse=midi.flat.notes
    for elements in elements_to_parse:
        if isinstance(elements,note.Note):
            notes.append(str(elements.pitch))
        elif isinstance(elements,chord.Chord):
            notes.append('+'.join(str(n) for n in elements.normalOrder))

# %%
print(len(notes))

# %%
with open("notes.pkl",'wb') as f:
    pickle.dump(notes,f)

# %%
print("total notes are ",len(notes))
print("total unique notes ",len(set(notes)))

# %%
sequence_length=100

# %%
pitchname=sorted(set(notes))

# %%
pitchname

# %%
ele_to_int=dict((ele,idx) for idx,ele in enumerate(pitchname))

# %%
ele_to_int

# %%
network_input=[]
network_output=[]
for i in range(len(notes)-sequence_length):
    seq_in=notes[i:i+sequence_length]
    seq_out=notes[i+sequence_length]
    
    network_input.append([ele_to_int[ch] for ch in seq_in])
    network_output.append(ele_to_int[seq_out])

# %%
print(len(network_input),network_input[0])
print(len(network_output))

# %%
n_patterns=len(network_input)

# %%
network_input=np.reshape(network_input,(n_patterns,sequence_length,1)) # converting it into 3d becaause lstm accepts in 3d

# %%
network_input.shape

# %%
n_vocab=len(set(notes))

# %%
normalised_netwrok_input=network_input/float(n_vocab)

# %%
#encoding netwrod output classes into one hot vector

# %%
network_output=np_utils.to_categorical((network_output))

# %%
print(network_output.shape)
print(normalised_netwrok_input.shape)

# %% [markdown]
# # create model

# %%
from keras.models import Sequential,load_model
from keras.layers import*
from keras.callbacks import EarlyStopping,ModelCheckpoint

# %%
model=Sequential()

# %%
model.add(LSTM(units=512,input_shape=(normalised_netwrok_input.shape[1],normalised_netwrok_input.shape[2]),return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(512,return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(512))
model.add(Dense(512))
model.add(Dropout(0.3))
model.add(Dense(n_vocab,activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam')

# %%
model.summary()

# %%
checkpoint=ModelCheckpoint("music_model.hdf5",verbose=0,monitor='loss',mode='min',save_best_only=True)
model_hist=model.fit(normalised_netwrok_input,network_output,epochs=100,callbacks=[checkpoint],batch_size=64)
# Out:
# WARNING:tensorflow:From c:\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/100
# 25600/61909 [===========>..................] - ETA: 58:45 - loss: 4.7058

# %%
#model trained on google colab annd model with least loss is saved so now loadi
model=load_model("music_model.hdf5")

# %% [markdown]
# # predictions

# %%
sequence_length=100
network_input=[]
for i in range(len(notes)-sequence_length):
    seq_in=notes[i:i+sequence_length]
    network_input.append([ele_to_int[ch] for ch in seq_in])

# %%
start=np.random.randint(len(network_input)-1)

int_to_ele=dict((num,ele) for num,ele enumerate(pitchname))

pattern=network_input[start]
prediction_output=[]

#predicting next 2000 notes
for note in range(2000):
    prediction_input=np.reshape(pattern,(1,len(pattern),1))
    prediction_input=prediction_input/float(n_vocab)
    
    prediction=model.predict(prediction_input,verbose=0)
    idx=np.argmax(prediction)
    
    result=int_to_ele[idx]
    
    prediction_output.append(result)
    
    pattern.append(idx)
    
    pattern=pattern[1:]

# %% [markdown]
# # creating midi file from prediction

# %%
offset=0   #time
output_notes=[]
for pattern in prediction_output:
    #if the pattern is the chord
    if ('+' in pattern) of pattern.isdigit():
        notes_in_chord=pattern.split('+')
        temp_notes=[]
        for current in notes_in_chord:
            new_note=new.Note(int(current))
            new_note.storedinstrument=instrument.Piano()
            temp_notes.append(new_note)
        
        new_chord=chord.Chord(temp_notes)
        new_chord.offset=offset
        output_notes.append(new_chord)
        
    #if patterns is note
    else:
        new_note=new.Note(pattern)
        new_chord.offset=offset
        new_note.storedinstrument=instrument.Piano()
        output_notes.append(new_note)
    offset+=0.5

# %%
#create stream object from the created file
midi_stream=stream.Stream(output_notes)
midi_stream.write('midi',fp='generated_midi.mid')

# %%
midi_stream.show('midi')
